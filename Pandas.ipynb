# %% [markdown]
# # Press Shift + Tab for information of any method

# %% [markdown]
# # DataFrame Basics

# %% [markdown]
# DataFrame is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table

# %%
import pandas as pd
import numpy as np
import sqlalchemy

# %%
df = pd.read_csv(r'C:\Users\shara\Desktop\MACHINE LEARNING\Pandas\weather data.csv')          #read_csv is a method
df
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017           32          6   Rain
# 1  01-02-2017           35          7  Sunny
# 2  01-03-2017           28          2   Snow
# 3  01-04-2017           24          7   Snow
# 4  01-05-2017           32          4   Rain
# 5  01-06-2017           31          2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
df[2:5]
# Out:
#           day  temperature  windspeed event
# 2  01-03-2017           28          2  Snow
# 3  01-04-2017           24          7  Snow
# 4  01-05-2017           32          4  Rain

# %%
df.head(2)
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017           32          6   Rain
# 1  01-02-2017           35          7  Sunny

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.day
# Out:
# 0    01-01-2017
# 1    01-02-2017
# 2    01-03-2017
# 3    01-04-2017
# 4    01-05-2017
# 5    01-06-2017
# Name: day, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['event','day']]
# Out:
#    event         day
# 0   Rain  01-01-2017
# 1  Sunny  01-02-2017
# 2   Snow  01-03-2017
# 3   Snow  01-04-2017
# 4   Rain  01-05-2017
# 5  Sunny  01-06-2017

# %%
df['temperature'].max()
# Out:
# 35

# %%
df['temperature'].mean()
# Out:
# 30.333333333333332

# %%
df.describe()              #describe and describe() are two different functions
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
df[df.temperature >=32]
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017           32          6   Rain
# 1  01-02-2017           35          7  Sunny
# 4  01-05-2017           32          4   Rain

# %%
df[df.temperature == df['temperature'].max()]
# Out:
#           day  temperature  windspeed  event
# 1  01-02-2017           35          7  Sunny

# %%
df['day'][df.temperature == df['temperature'].max()]
# Out:
# 1    01-02-2017
# Name: day, dtype: object

# %%
df.reset_index()
# Out:
#    index         day  temperature  windspeed  event
# 0      0  01-01-2017           32          6   Rain
# 1      1  01-02-2017           35          7  Sunny
# 2      2  01-03-2017           28          2   Snow
# 3      3  01-04-2017           24          7   Snow
# 4      4  01-05-2017           32          4   Rain
# 5      5  01-06-2017           31          2  Sunny

# %% [markdown]
# # Different ways to create dataframe

# %% [markdown]
# For excel file
#
# df = pd.read_excel("name_of_file.xlsx" , "Sheet_name")

# %%
#using a dictionary
dict = {
    'day' : ['1' , '2' , '3'],
    'temp' : ['25' , '30' , '27'],
    'event' : ['rain' , 'rain' , 'rain']
}
df1 = pd.DataFrame(dict)
df1
# Out:
#   day temp event
# 0   1   25  rain
# 1   2   30  rain
# 2   3   27  rain

# %%
weather = [
    (1,25,'rain'),
    (2,30,'rain'),
    (3,27,'rain')
]
df2 = pd.DataFrame(weather,columns = ["day","temp","event"])
df2
# Out:
#    day  temp event
# 0    1    25  rain
# 1    2    30  rain
# 2    3    27  rain

# %% [markdown]
# We can also create by a list of dictionaries

# %% [markdown]
# # Reading and writing in csv and excel files

# %%
df3 = pd.read_csv(r'C:\Users\shara\Desktop\MACHINE LEARNING\Pandas\weather data.csv',header = None)
df3
# Out:
#             0            1          2      3
# 0         day  temperature  windspeed  event
# 1  01-01-2017           32          6   Rain
# 2  01-02-2017           35          7  Sunny
# 3  01-03-2017           28          2   Snow
# 4  01-04-2017           24          7   Snow
# 5  01-05-2017           32          4   Rain
# 6  01-06-2017           31          2  Sunny

# %% [markdown]
# To give your own names to the headers:-

# %% [markdown]
# df3 = pd.read_csv(r'C:\Users\shara\Desktop\MACHINE LEARNING\Pandas\weather data.csv',header = None,names =[" , , , "])

# %%
df3 = pd.read_csv(r'C:\Users\shara\Desktop\MACHINE LEARNING\Pandas\weather data.csv',nrows = 3)
df3          #To print only 3 rows
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017           32          6   Rain
# 1  01-02-2017           35          7  Sunny
# 2  01-03-2017           28          2   Snow

# %% [markdown]
# To replace unwanted values with NaN which python shows for missing data , then use
# na_values = ["unwanted_value_1","unwanted_value_2"] in the pd.read_csv box just like the previous ones
#
# We can also use this feature for a single columns like :-
#
#         na_values = {
#             "column_name_1" = [list of unwanted things],
#             "column_name_2" = [list of unwanted things]
#             }

# %% [markdown]
# To create a csv file use :-
#
# df.to_csv("csv file name" , columns = [specific columns you want to transfer] , index = False)

# %%
df4 = pd.read_excel(r'C:\Users\shara\Desktop\EXCEL\Book1.xlsx','Sheet1')
df4 = df4[:51]
df4
# Out:
#    BRANCH  YEAR                                SUBJECT  \
# 0     cse   2.0                         DATA STRUCTURE
# 1     cse   2.0                         DATA STRUCTURE
# 2     idk   2.0                         DATA STRUCTURE
# 3     cse   2.0                         DATA STRUCTURE
# 4     cse   2.0                         DATA STRUCTURE
# 5     cse   2.0                         DATA STRUCTURE
# 6     idk   2.0                                 MATH-3
# 7     cse   2.0                                 MATH-3
# 8     cse   2.0                                 MATH-3
# 9     cse   2.0                        MICROPROCESSORS
# 10    cse   2.0                              ECONOMICS
# 11    idk   2.0                              ECONOMICS
# 12    cse   2.0                              ECONOMICS
# 13    cse   2.0                              ECONOMICS
# 14    cse   2.0                              ECONOMICS
# 15    cse   2.0                              ECONOMICS
# ...

# %% [markdown]
# def convert_people_cell(cell):
#
#     if cell=="n.a.":
#         return 'Sam Walton'
#     return cell
#
# def convert_price_cell(cell):
#
#     if cell=="n.a.":
#         return 50
#     return cell
#
# df = pd.read_excel("stock_data.xlsx","Sheet1", converters= {
#
#         'people': convert_people_cell,
#         'price': convert_price_cell
#     })
#
# df

# %%
def convert_branch(cell):
    if cell == 'idk':
        return 'cse'
    return cell
def convert_books(cell):
    if cell == 'some book':
        return None
    return cell
df4 = pd.read_excel(r'C:\Users\shara\Desktop\EXCEL\Book1.xlsx','Sheet1', converters = {
    'BRANCH' : convert_branch , 
    'BOOK PREFERENCE' : convert_books
})
df4 = df4[:51]
df4
# Out:
#    BRANCH  YEAR                                SUBJECT  \
# 0     cse   2.0                         DATA STRUCTURE
# 1     cse   2.0                         DATA STRUCTURE
# 2     cse   2.0                         DATA STRUCTURE
# 3     cse   2.0                         DATA STRUCTURE
# 4     cse   2.0                         DATA STRUCTURE
# 5     cse   2.0                         DATA STRUCTURE
# 6     cse   2.0                                 MATH-3
# 7     cse   2.0                                 MATH-3
# 8     cse   2.0                                 MATH-3
# 9     cse   2.0                        MICROPROCESSORS
# 10    cse   2.0                              ECONOMICS
# 11    cse   2.0                              ECONOMICS
# 12    cse   2.0                              ECONOMICS
# 13    cse   2.0                              ECONOMICS
# 14    cse   2.0                              ECONOMICS
# 15    cse   2.0                              ECONOMICS
# ...

# %% [markdown]
# Above code converts the wrong info to info that we want

# %% [markdown]
# # Missing data

# %%
df1 = pd.read_csv(r'C:\Users\shara\Desktop\MACHINE LEARNING\Pandas\weather_data.csv')
df1
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2017         32.0        6.0    Rain
# 1  01-04-2017          NaN        9.0   Sunny
# 2  01-05-2017         28.0        NaN    Snow
# 3  01-06-2017          NaN        7.0     NaN
# 4  01-07-2017         32.0        NaN    Rain
# 5  01-08-2017          NaN        NaN   Sunny
# 6  01-09-2017          NaN        NaN     NaN
# 7  01-10-2017         34.0        8.0  Cloudy
# 8  01-11-2017         40.0       12.0   Sunny

# %%
type(df1.day[0])
# Out:
# str

# %% [markdown]
# To convert this str into into timestamp , we use parse_dates=["day"]

# %%
df1 = pd.read_csv(r'C:\Users\shara\Desktop\MACHINE LEARNING\Pandas\weather_data.csv',parse_dates = ["day"])
df1
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
type(df1.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
new_df = df1.fillna(0)
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          0.0        9.0   Sunny
# 2 2017-01-05         28.0        0.0    Snow
# 3 2017-01-06          0.0        7.0       0
# 4 2017-01-07         32.0        0.0    Rain
# 5 2017-01-08          0.0        0.0   Sunny
# 6 2017-01-09          0.0        0.0       0
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df1.fillna({
    'temperature' : 0 ,
    'windspeed' : 0 ,
    'event' : 'No event'
})
new_df
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01         32.0        6.0      Rain
# 1 2017-01-04          0.0        9.0     Sunny
# 2 2017-01-05         28.0        0.0      Snow
# 3 2017-01-06          0.0        7.0  No event
# 4 2017-01-07         32.0        0.0      Rain
# 5 2017-01-08          0.0        0.0     Sunny
# 6 2017-01-09          0.0        0.0  No event
# 7 2017-01-10         34.0        8.0    Cloudy
# 8 2017-01-11         40.0       12.0     Sunny

# %%
new_df = df1.fillna(method = 'ffill')           #ffill is used so that the previous data gets copied in the missing place
new_df     #ffill = forward fill  ,  bfill = backward fill
#To copy data from adjacent column , then we can use another argument :- axis = 'columns'
#We can use limit argument to specify that how mny rows do we want ffill to work
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         32.0        9.0   Sunny
# 2 2017-01-05         28.0        9.0    Snow
# 3 2017-01-06         28.0        7.0    Snow
# 4 2017-01-07         32.0        7.0    Rain
# 5 2017-01-08         32.0        7.0   Sunny
# 6 2017-01-09         32.0        7.0   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df1.interpolate()      #Average of the upper and lower cell
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01    32.000000       6.00    Rain
# 1 2017-01-04    30.000000       9.00   Sunny
# 2 2017-01-05    28.000000       8.00    Snow
# 3 2017-01-06    30.000000       7.00     NaN
# 4 2017-01-07    32.000000       7.25    Rain
# 5 2017-01-08    32.666667       7.50   Sunny
# 6 2017-01-09    33.333333       7.75     NaN
# 7 2017-01-10    34.000000       8.00  Cloudy
# 8 2017-01-11    40.000000      12.00   Sunny

# %% [markdown]
# Interpolate method did provide with a middle value but our temp should be more near to 2017-01-04 so we could use a method called as time but for that we need to have an index which is of datetimestamp ,so...

# %%
df1.set_index('day',inplace = True)

# %%
new_df = df1.interpolate(method = "time")
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %% [markdown]
# Now in this one 2nd row temp is 29 and more closer to 3rd row because of date , there are many more methods to check on pandas official site

# %%
new_df1 = df1.dropna()      #drops the row if it has atleast one NaN
new_df1
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df1 = df1.dropna(how = 'all')      #drops the row if all are NaN
new_df1
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df1 = df1.dropna(thresh = 2)      #we can specify the number of data we want by thresh 
new_df1                               #This one states the number of NaN in a row to drop
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-07         32.0        NaN    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
dt = pd.date_range("01-01-2017","01-11-2017")    #to fill the dates between 2017-01-01 and 2017-01-04
idx = pd.DatetimeIndex(dt)
df1 = df1.reindex(idx)
df1
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# # Using replace function for missing data

# %%
df1 = pd.read_csv(r'C:\Users\shara\Desktop\MACHINE LEARNING\Pandas\weather_data_6.csv')
df1
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017           32          6   Rain
# 1  01-02-2017       -99999          7  Sunny
# 2  01-03-2017           28     -99999   Snow
# 3  01-04-2017       -99999          7      0
# 4  01-05-2017           32     -88888   Rain
# 5  01-06-2017           31          2  Sunny
# 6  01-06-2017           34          5      0

# %%
new_df = df1.replace([-99999,-88888],np.NaN)
new_df
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017         32.0        6.0   Rain
# 1  01-02-2017          NaN        7.0  Sunny
# 2  01-03-2017         28.0        NaN   Snow
# 3  01-04-2017          NaN        7.0      0
# 4  01-05-2017         32.0        NaN   Rain
# 5  01-06-2017         31.0        2.0  Sunny
# 6  01-06-2017         34.0        5.0      0

# %%
new_df = df1.replace({
    'temperature' : -99999,
    'windspeed' : [-99999,-88888],
    'event' : 0
},np.NaN)
new_df
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017         32.0        6.0   Rain
# 1  01-02-2017          NaN        7.0  Sunny
# 2  01-03-2017         28.0        NaN   Snow
# 3  01-04-2017          NaN        7.0      0
# 4  01-05-2017         32.0        NaN   Rain
# 5  01-06-2017         31.0        2.0  Sunny
# 6  01-06-2017         34.0        5.0      0

# %%
new_df = df1.replace({
    -99999 : np.NaN,
    'Snow' : 'Snowing'
})
new_df
# Out:
#           day  temperature  windspeed    event
# 0  01-01-2017         32.0        6.0     Rain
# 1  01-02-2017          NaN        7.0    Sunny
# 2  01-03-2017         28.0        NaN  Snowing
# 3  01-04-2017          NaN        7.0        0
# 4  01-05-2017         32.0   -88888.0     Rain
# 5  01-06-2017         31.0        2.0    Sunny
# 6  01-06-2017         34.0        5.0        0

# %%
df_new = pd.DataFrame({
    'score': ['exceptional','average', 'good', 'poor', 'average', 'exceptional'],
    'student': ['rob', 'maya', 'parthiv', 'tom', 'julian', 'erica']
})
df_new
# Out:
#          score  student
# 0  exceptional      rob
# 1      average     maya
# 2         good  parthiv
# 3         poor      tom
# 4      average   julian
# 5  exceptional    erica

# %%
df_new_1 = df_new.replace(['exceptional' , 'good' ,'average', 'poor'],['A','B','C','D'])
df_new_1
# Out:
#   score  student
# 0     A      rob
# 1     C     maya
# 2     B  parthiv
# 3     D      tom
# 4     C   julian
# 5     A    erica

# %% [markdown]
# # Group By

# %%
df7 = pd.read_csv(r'C:\Users\shara\Desktop\MACHINE LEARNING\Pandas\weather_data_by_cities.csv')
df7
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york           32          6    Rain
# 1   01-02-2017  new york           36          7   Sunny
# 2   01-03-2017  new york           28         12    Snow
# 3   01-04-2017  new york           33          7   Sunny
# 4   01-01-2017    mumbai           90          5   Sunny
# 5   01-02-2017    mumbai           85         12     Fog
# 6   01-03-2017    mumbai           87         15     Fog
# 7   01-04-2017    mumbai           92          5    Rain
# 8   01-01-2017     paris           45         20   Sunny
# 9   01-02-2017     paris           50         13  Cloudy
# 10  01-03-2017     paris           54          8  Cloudy
# 11  01-04-2017     paris           42         10  Cloudy

# %%
a = df7.groupby('city')
a          #its like a tuple where we access index and value of a tuple

# %%
for city , city_df in a:
    print(city)
    print(city_df)
# Out:
# mumbai
#           day    city  temperature  windspeed  event
# 4  01-01-2017  mumbai           90          5  Sunny
# 5  01-02-2017  mumbai           85         12    Fog
# 6  01-03-2017  mumbai           87         15    Fog
# 7  01-04-2017  mumbai           92          5   Rain
# new york
#           day      city  temperature  windspeed  event
# 0  01-01-2017  new york           32          6   Rain
# 1  01-02-2017  new york           36          7  Sunny
# 2  01-03-2017  new york           28         12   Snow
# 3  01-04-2017  new york           33          7  Sunny
# paris
#            day   city  temperature  windspeed   event
# 8   01-01-2017  paris           45         20   Sunny
# 9   01-02-2017  paris           50         13  Cloudy
# 10  01-03-2017  paris           54          8  Cloudy
# 11  01-04-2017  paris           42         10  Cloudy

# %%
a.get_group('mumbai')
# Out:
#           day    city  temperature  windspeed  event
# 4  01-01-2017  mumbai           90          5  Sunny
# 5  01-02-2017  mumbai           85         12    Fog
# 6  01-03-2017  mumbai           87         15    Fog
# 7  01-04-2017  mumbai           92          5   Rain

# %%
a.max()       #Gives the max columns for each city
# Out:
#                  day  temperature  windspeed  event
# city
# mumbai    01-04-2017           92         15  Sunny
# new york  01-04-2017           36         12  Sunny
# paris     01-04-2017           54         20  Sunny

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a.mean()
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
a.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
# %matplotlib inline
a.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.125;0.775x0.755)
# new york    AxesSubplot(0.125,0.125;0.775x0.755)
# paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# # Concat

# %%
india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
pd.concat([india_weather,us_weather],ignore_index = True)    #ignore_index used for a continous indexing
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
df8 = pd.concat([india_weather,us_weather],keys = {'india','us'})
df8
# Out:
#              city  temperature  humidity
# india 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# us    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
df8.loc['india']
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
temperature_df = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
}, index=[0,1,2])
temperature_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed_df = pd.DataFrame({
    "city": ["delhi","mumbai","banglore"],
    "windspeed": [7,12,9],
}, index=[1,0,2])
windspeed_df
# Out:
#        city  windspeed
# 1     delhi          7
# 0    mumbai         12
# 2  banglore          9

# %%
df = pd.concat([temperature_df,windspeed_df],axis=1)
df
# Out:
#        city  temperature      city  windspeed
# 0    mumbai           32    mumbai         12
# 1     delhi           45     delhi          7
# 2  banglore           30  banglore          9

# %%
s = pd.Series(["Humid","Dry","Rain"], name="event")
s
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: event, dtype: object

# %%
df8 = pd.concat([temperature_df,s],axis=1)
df8
# Out:
#        city  temperature  event
# 0    mumbai           32  Humid
# 1     delhi           45    Dry
# 2  banglore           30   Rain

# %% [markdown]
# # Merge Command or Joins

# %%
df9 = pd.merge(temperature_df,windspeed_df,on = 'city')
df9
# Out:
#        city  temperature  windspeed
# 0    mumbai           32         12
# 1     delhi           45          7
# 2  banglore           30          9

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35, 38],
})
df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "humidity": [65,68,71],
})
df2
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        71

# %%
df3=pd.merge(df1,df2,on="city")      #inner join 
df3
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65

# %%
#for outer join or union
df3=pd.merge(df1,df2,on="city",how="outer",indicator = True)
df3
# Out:
#         city  temperature  humidity      _merge
# 0   new york         21.0      68.0        both
# 1    chicago         14.0      65.0        both
# 2    orlando         35.0       NaN   left_only
# 3  baltimore         38.0       NaN   left_only
# 4  san diego          NaN      71.0  right_only

# %%
df3=pd.merge(df1,df2,on="city",how="left")
df3
# Out:
#         city  temperature  humidity
# 0   new york           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           38       NaN

# %% [markdown]
# # Pivot and Pivot Tables

# %%
df10 = pd.read_csv(r'C:\Users\shara\Desktop\MACHINE LEARNING\Pandas\weather_pivot.csv')
df10
# Out:
#          date      city  temperature  humidity
# 0  05-01-2017  new york           65        56
# 1  05-02-2017  new york           66        58
# 2  05-03-2017  new york           68        60
# 3  05-01-2017    mumbai           75        80
# 4  05-02-2017    mumbai           78        83
# 5  05-03-2017    mumbai           82        85
# 6  05-01-2017   beijing           80        26
# 7  05-02-2017   beijing           77        30
# 8  05-03-2017   beijing           79        35

# %%
df10.pivot(index = 'date' , columns = 'city')
# Out:
#            temperature                 humidity
# city           beijing mumbai new york  beijing mumbai new york
# date
# 05-01-2017          80     75       65       26     80       56
# 05-02-2017          77     78       66       30     83       58
# 05-03-2017          79     82       68       35     85       60

# %%
df10.pivot(index = 'date' , columns = 'city',values= 'humidity')
# Out:
# city        beijing  mumbai  new york
# date
# 05-01-2017       26      80        56
# 05-02-2017       30      83        58
# 05-03-2017       35      85        60

# %%
df10 = pd.read_csv(r'C:\Users\shara\Desktop\MACHINE LEARNING\Pandas\weather_pivot_2.csv')
df10
# Out:
#          date      city  temperature  humidity
# 0  05-01-2017  new york           65        56
# 1  05-01-2017  new york           61        54
# 2  05-02-2017  new york           70        60
# 3  05-02-2017  new york           72        62
# 4  05-01-2017    mumbai           75        80
# 5  05-01-2017    mumbai           78        83
# 6  05-02-2017    mumbai           82        85
# 7  05-02-2017    mumbai           80        26

# %%
df10.pivot_table(index = 'city' , columns = 'date' , aggfunc = 'sum')    #by default function is average
# Out:
#            humidity            temperature
# date     05-01-2017 05-02-2017  05-01-2017 05-02-2017
# city
# mumbai          163        111         153        162
# new york        110        122         126        142

# %% [markdown]
# Also learn about the grouper

# %% [markdown]
# # Reshaping using melt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df11 = pd.read_csv(r'C:\Users\shara\Desktop\MACHINE LEARNING\Pandas\weather_melt.csv')
df11
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
new_df11 = pd.melt(df11, id_vars = ["day"],var_name = "city" , value_name = "temperature")      #the column that we dont want to change is in id_vars
new_df11
# Out:
#           day     city  temperature
# 0      Monday  chicago           32
# 1     Tuesday  chicago           30
# 2   Wednesday  chicago           28
# 3    Thursday  chicago           22
# 4      Friday  chicago           30
# 5    Saturday  chicago           20
# 6      Sunday  chicago           25
# 7      Monday  chennai           75
# 8     Tuesday  chennai           77
# 9   Wednesday  chennai           75
# 10   Thursday  chennai           82
# 11     Friday  chennai           83
# 12   Saturday  chennai           81
# 13     Sunday  chennai           77
# 14     Monday   berlin           41
# 15    Tuesday   berlin           43
# 16  Wednesday   berlin           45
# 17   Thursday   berlin           38
# 18     Friday   berlin           30
# 19   Saturday   berlin           45
# 20     Sunday   berlin           47

# %%
new_df11[new_df11["city"]=="chicago"]
# Out:
#          day     city  temperature
# 0     Monday  chicago           32
# 1    Tuesday  chicago           30
# 2  Wednesday  chicago           28
# 3   Thursday  chicago           22
# 4     Friday  chicago           30
# 5   Saturday  chicago           20
# 6     Sunday  chicago           25

# %% [markdown]
# # Stack and Unstack

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df12 = pd.read_excel('stocks.xlsx',header = [0,1])
df12
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
df12.stack()
# Out:
#               Price  Price to earnings ratio (P/E) Unnamed: 0_level_0
# 0 Company       NaN                            NaN         2017-06-05
#   Facebook    155.0                          37.10                NaT
#   Google      955.0                          32.00                NaT
#   Microsoft    66.0                          30.31                NaT
# 1 Company       NaN                            NaN         2017-06-06
#   Facebook    150.0                          36.98                NaT
#   Google      987.0                          31.30                NaT
#   Microsoft    69.0                          30.56                NaT
# 2 Company       NaN                            NaN         2017-06-07
#   Facebook    153.0                          36.78                NaT
#   Google      963.0                          31.70                NaT
#   Microsoft    62.0                          30.46                NaT
# ...

# %%
df12.stack(level = 0 , dropna = True)
# Out:
#                                    Company  Facebook  Google  Microsoft
# 0 Price                                NaT    155.00   955.0      66.00
#   Price to earnings ratio (P/E)        NaT     37.10    32.0      30.31
#   Unnamed: 0_level_0            2017-06-05       NaN     NaN        NaN
# 1 Price                                NaT    150.00   987.0      69.00
#   Price to earnings ratio (P/E)        NaT     36.98    31.3      30.56
#   Unnamed: 0_level_0            2017-06-06       NaN     NaN        NaN
# 2 Price                                NaT    153.00   963.0      62.00
#   Price to earnings ratio (P/E)        NaT     36.78    31.7      30.46
#   Unnamed: 0_level_0            2017-06-07       NaN     NaN        NaN
# 3 Price                                NaT    155.00  1000.0      61.00
#   Price to earnings ratio (P/E)        NaT     36.11    31.2      30.11
#   Unnamed: 0_level_0            2017-06-08       NaN     NaN        NaN
# ...

# %% [markdown]
# # CrossTabs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It is used for frequency distribution

# %%
df13 = pd.read_excel("survey.xls")
df13
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima   Bangadesh  Female   31       Left
# 5    Kadir   Bangadesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
pd.crosstab(df13.Sex , df13.Handedness, margins = True)
# Out:
# Handedness  Left  Right  All
# Sex
# Female         2      3    5
# Male           5      2    7
# All            7      5   12

# %%
pd.crosstab(df13.Sex , [df13.Handedness,df13.Nationality], margins = True)
# Out:
# Handedness       Left                 Right           All
# Nationality Bangadesh China India USA China India USA
# Sex
# Female              1     1     0   0     1     0   2   5
# Male                1     1     2   1     0     1   1   7
# All                 2     2     2   1     1     1   3  12

# %%
pd.crosstab(df13.Sex , df13.Handedness, values = df13.Age , aggfunc = np.average)
# Out:
# Handedness  Left  Right
# Sex
# Female      44.5   31.0
# Male        31.2   28.0

# %% [markdown]
# # SQL tables - read and write

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:root@localhost:3306/sakila')

# %%
df14 = pd.read_sql_table('city',engine)
df14
# Out:
#      city_id                city  country_id         last_update
# 0          1  A Corua (La Corua)          87 2006-02-15 04:45:25
# 1          2                Abha          82 2006-02-15 04:45:25
# 2          3           Abu Dhabi         101 2006-02-15 04:45:25
# 3          4                Acua          60 2006-02-15 04:45:25
# 4          5               Adana          97 2006-02-15 04:45:25
# ..       ...                 ...         ...                 ...
# 595      596               Zaria          69 2006-02-15 04:45:25
# 596      597        Zeleznogorsk          80 2006-02-15 04:45:25
# 597      598         Zhezqazghan          51 2006-02-15 04:45:25
# 598      599            Zhoushan          23 2006-02-15 04:45:25
# 599      600          Ziguinchor          83 2006-02-15 04:45:25
#
# [600 rows x 4 columns]

# %%
query = '''
SELECT A.CITY , B.COUNTRY
FROM CITY A 
INNER JOIN COUNTRY B
ON A.COUNTRY_ID = B.COUNTRY_ID
'''
df14 = pd.read_sql_query(query,engine)
df14
# Out:
#            CITY         COUNTRY
# 0         Kabul     Afghanistan
# 1         Batna         Algeria
# 2         Bchar         Algeria
# 3        Skikda         Algeria
# 4        Tafuna  American Samoa
# ..          ...             ...
# 595       Sanaa           Yemen
# 596       Taizz           Yemen
# 597  Kragujevac      Yugoslavia
# 598    Novi Sad      Yugoslavia
# 599       Kitwe          Zambia
#
# [600 rows x 2 columns]

# %% [markdown]
# To write to a sql table

# %%
df14 = pd.DataFrame({
    'actor_id' : [201,202,203],
    'first_name' : ['sharad' , 'vinay' ,'anurag'],
    'last_name' : ['nahata' , 'nahata' , 'nahata'],
    'last_update' : ['2006-02-15 04:34:33','2006-02-15 04:34:33','2006-02-15 04:34:33']
})
df14
# Out:
#    actor_id first_name last_name          last_update
# 0       201     sharad    nahata  2006-02-15 04:34:33
# 1       202      vinay    nahata  2006-02-15 04:34:33
# 2       203     anurag    nahata  2006-02-15 04:34:33

# %%
#P.S. - dont run this again
df14.to_sql(
    name = 'actor',
    con = engine,
    index = False,
    if_exists = 'append'
)       #for the result , check mysql actor table in sakila

# %% [markdown]
# # Time series Analysis

# %% [markdown]
# Using date as an index is very helpful

# %%
df15 = pd.read_csv("aapl.csv" , parse_dates = ["Date"] , index_col = "Date")
df15.head()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107

# %%
df15["2017-01"].Close.mean()      #mean closing value in january 2017
# Out:
# 119.57000000000001

# %%
df15["2017-01-05"]
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-01-05  115.92  116.86  115.81  116.61  22193587

# %%
df15.Close.resample("M").mean()         #monthly average data
# Out:
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# 2016-12-31    114.335714
# 2017-01-31    119.570000
# 2017-02-28    133.713684
# 2017-03-31    140.617826
# 2017-04-30    142.886842
# 2017-05-31    152.227727
# 2017-06-30    147.831364
# 2017-07-31    143.625000
# Freq: M, Name: Close, dtype: float64

# %%
# %matplotlib inline
df15.Close.resample("M").mean().plot()      #we can use resample to define the frequency

# %%
df15.Close.resample("Q").mean().plot(kind = "bar")

# %%
df16 = pd.read_csv("aapl_no_data.csv")
df16
# Out:
#       Open    High     Low   Close    Volume
# 0   153.17  153.33  152.22  153.18  16404088
# 1   153.58  155.45  152.89  155.45  27770715
# 2   154.34  154.45  153.46  153.93  25331662
# 3   153.90  155.81  153.78  154.45  26624926
# 4   155.02  155.98  154.48  155.37  21069647
# 5   155.25  155.54  154.40  154.99  21250798
# 6   155.19  155.19  146.02  148.98  64882657
# 7   145.74  146.09  142.51  145.42  72307330
# 8   147.16  147.45  145.15  146.59  34165445
# 9   147.50  147.50  143.84  145.16  31531232
# 10  143.32  144.48  142.21  144.29  32165373
# 11  143.78  144.50  142.20  142.27  50361093
# 12  143.66  146.74  143.66  146.34  32541404
# 13  146.87  146.87  144.94  145.01  24900073
# 14  145.52  146.07  144.61  145.87  21265751
# 15  145.77  146.70  145.12  145.63  19106294
# 16  145.13  147.16  145.11  146.28  35439389
# 17  147.17  148.28  145.38  145.82  25692361
# 18  145.01  146.16  143.62  143.73  24761891
# 19  144.49  146.11  143.16  145.83  22082432
# ...

# %%
rng = pd.date_range(start = "6/1/2017" , end = "6/30/2017" , freq = "B")  #B for business days
rng
# Out:
# DatetimeIndex(['2017-06-01', '2017-06-02', '2017-06-05', '2017-06-06',
#                '2017-06-07', '2017-06-08', '2017-06-09', '2017-06-12',
#                '2017-06-13', '2017-06-14', '2017-06-15', '2017-06-16',
#                '2017-06-19', '2017-06-20', '2017-06-21', '2017-06-22',
#                '2017-06-23', '2017-06-26', '2017-06-27', '2017-06-28',
#                '2017-06-29', '2017-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
df16.set_index(rng , inplace = True)
df16
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-19  143.66  146.74  143.66  146.34  32541404
# 2017-06-20  146.87  146.87  144.94  145.01  24900073
# 2017-06-21  145.52  146.07  144.61  145.87  21265751
# 2017-06-22  145.77  146.70  145.12  145.63  19106294
# 2017-06-23  145.13  147.16  145.11  146.28  35439389
# ...

# %%
# %matplotlib inline
df16.Close.plot()

# %%
df16.asfreq('D',method = "pad")
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-03  153.58  155.45  152.89  155.45  27770715
# 2017-06-04  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-10  155.19  155.19  146.02  148.98  64882657
# 2017-06-11  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-17  143.78  144.50  142.20  142.27  50361093
# ...

# %%
new_rng = pd.date_range(start = "1/1/2020" , periods = 22 , freq = "B")
new_rng
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-20', '2020-01-21', '2020-01-22',
#                '2020-01-23', '2020-01-24', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# # Holidays

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

# %%
us_cal = CustomBusinessDay(calendar=USFederalHolidayCalendar())   #exceludes both weekends and usa holidays

rng = pd.date_range(start="7/1/2017",end="8/2/2017", freq=us_cal)
rng
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-05', '2017-07-06', '2017-07-07',
#                '2017-07-10', '2017-07-11', '2017-07-12', '2017-07-13',
#                '2017-07-14', '2017-07-17', '2017-07-18', '2017-07-19',
#                '2017-07-20', '2017-07-21', '2017-07-24', '2017-07-25',
#                '2017-07-26', '2017-07-27', '2017-07-28', '2017-07-31',
#                '2017-08-01', '2017-08-02'],
#               dtype='datetime64[ns]', freq='C')

# %%
df17 = pd.read_csv("aapl_no_data.csv")
df17.set_index(rng,inplace = True)
df17
# Out:
#               Open    High     Low   Close    Volume
# 2017-07-03  153.17  153.33  152.22  153.18  16404088
# 2017-07-05  153.58  155.45  152.89  155.45  27770715
# 2017-07-06  154.34  154.45  153.46  153.93  25331662
# 2017-07-07  153.90  155.81  153.78  154.45  26624926
# 2017-07-10  155.02  155.98  154.48  155.37  21069647
# 2017-07-11  155.25  155.54  154.40  154.99  21250798
# 2017-07-12  155.19  155.19  146.02  148.98  64882657
# 2017-07-13  145.74  146.09  142.51  145.42  72307330
# 2017-07-14  147.16  147.45  145.15  146.59  34165445
# 2017-07-17  147.50  147.50  143.84  145.16  31531232
# 2017-07-18  143.32  144.48  142.21  144.29  32165373
# 2017-07-19  143.78  144.50  142.20  142.27  50361093
# 2017-07-20  143.66  146.74  143.66  146.34  32541404
# 2017-07-21  146.87  146.87  144.94  145.01  24900073
# 2017-07-24  145.52  146.07  144.61  145.87  21265751
# 2017-07-25  145.77  146.70  145.12  145.63  19106294
# 2017-07-26  145.13  147.16  145.11  146.28  35439389
# ...

# %%
from pandas.tseries.holiday import AbstractHolidayCalendar, nearest_workday, Holiday
class myCalendar(AbstractHolidayCalendar):
    rules = [
        Holiday('My Birth Day', month=5, day=17),#, observance=nearest_workday),
    ]
    
my_bday = CustomBusinessDay(calendar=myCalendar())
pd.date_range('5/1/2017','5/30/2017',freq=my_bday)
# Out:
# DatetimeIndex(['2017-05-01', '2017-05-02', '2017-05-03', '2017-05-04',
#                '2017-05-05', '2017-05-08', '2017-05-09', '2017-05-10',
#                '2017-05-11', '2017-05-12', '2017-05-15', '2017-05-16',
#                '2017-05-18', '2017-05-19', '2017-05-22', '2017-05-23',
#                '2017-05-24', '2017-05-25', '2017-05-26', '2017-05-29',
#                '2017-05-30'],
#               dtype='datetime64[ns]', freq='C')

# %%
egypt_weekdays = "Sun Mon Tue Wed Thu"

b = CustomBusinessDay(weekmask=egypt_weekdays)

pd.date_range(start="7/1/2017",periods=20,freq=b)
# Out:
# DatetimeIndex(['2017-07-02', '2017-07-03', '2017-07-04', '2017-07-05',
#                '2017-07-06', '2017-07-09', '2017-07-10', '2017-07-11',
#                '2017-07-12', '2017-07-13', '2017-07-16', '2017-07-17',
#                '2017-07-18', '2017-07-19', '2017-07-20', '2017-07-23',
#                '2017-07-24', '2017-07-25', '2017-07-26', '2017-07-27'],
#               dtype='datetime64[ns]', freq='C')

# %%
b = CustomBusinessDay(holidays=['2017-07-04', '2017-07-10'], weekmask=egypt_weekdays)

pd.date_range(start="7/1/2017",periods=20,freq=b)
# Out:
# DatetimeIndex(['2017-07-02', '2017-07-03', '2017-07-05', '2017-07-06',
#                '2017-07-09', '2017-07-11', '2017-07-12', '2017-07-13',
#                '2017-07-16', '2017-07-17', '2017-07-18', '2017-07-19',
#                '2017-07-20', '2017-07-23', '2017-07-24', '2017-07-25',
#                '2017-07-26', '2017-07-27', '2017-07-30', '2017-07-31'],
#               dtype='datetime64[ns]', freq='C')

# %% [markdown]
# # to_datetime func

# %%
dates = ['2017-01-05', 'Jan 5, 2017', '01/05/2017', '2017.01.05', '2017/01/05','20170105']
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2017-01-05', '2017-01-05', '2017-01-05', '2017-01-05',
#                '2017-01-05', '2017-01-05'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime("17/05/2001",dayfirst = True)
# Out:
# Timestamp('2001-05-17 00:00:00')

# %%
t = 1595442501
pd.to_datetime(t,unit = 's')
# Out:
# Timestamp('2020-07-22 18:28:21')

# %%
y = pd.Period('2019')
y
# Out:
# Period('2019', 'A-DEC')

# %%
dir(y)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_delta',
#  '_from_ordinal',
#  '_maybe_convert_freq',
#  '_typ',
#  'asfreq',
#  'day',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
#  'end_time',
#  'freq',
#  'freqstr',
#  'hour',
#  'is_leap_year',
#  'minute',
#  'month',
#  'now',
#  'ordinal',
#  'quarter',
#  'qyear',
#  'second',
#  'start_time',
#  'strftime',
#  'to_timestamp',
#  'week',
#  'weekday',
#  'weekofyear',
#  'year']
